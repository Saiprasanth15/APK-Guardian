# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
df=pd.read_csv('graphs (2).csv')
df
# Out:
#    Algorithm    Type  Feature Subset Selection Method  Accuracy(%)  \
# 0        SVM   Filter                             PCM       61.337
# 1        SVM   Filter                              CS       81.384
# 2        SVM   Filter                             Ano       82.300
# 3        SVM   Filter                              IG       79.236
# 4        SVM  Wrapper                             SFS       82.500
# 5        SVM  Wrapper                             SBE       81.000
# 6        KNN   Filter                             PCM       62.768
# 7        KNN   Filter                              CS       78.998
# 8        KNN   Filter                             Ano       80.907
# 9        KNN   Filter                              IG       79.952
# 10       KNN  Wrapper                             SFS       83.700
# 11       KNN  Wrapper                             SBE       82.800
# 12        NB   Filter                             PCM       69.690
# ...

# %%
df_svm=df[df.Algorithm=='SVM']
df_knn=df[df.Algorithm=='KNN']
df_nb=df[df.Algorithm=='NB']
df_cs=df[df['Feature Subset Selection Method']=='PCM']
df_cs['Accuracy(%)'].mean()
# Out:
# 64.59833333333334

# %%
df_svm.plot(x='Feature Subset Selection Method',y=['Accuracy(%)','Precision(%)','Recall(%)','F1-Score(%)'],kind='bar',title='SVM')
plt.legend(["Accuracy(%)","Precision(%)","Recall(%)","F1-Score(%)"],
           bbox_to_anchor = (1.05, 0.6))

# %%
df_knn.plot(x='Feature Subset Selection Method',y=['Accuracy(%)','Precision(%)','Recall(%)','F1-Score(%)'],kind='bar',title='KNN')
plt.legend(["Accuracy(%)","Precision(%)","Recall(%)","F1-Score(%)"],
           bbox_to_anchor = (1.05, 0.6))

# %%
df_nb.plot(x='Feature Subset Selection Method',y=['Accuracy(%)','Precision(%)','Recall(%)','F1-Score(%)'],kind='bar',title='NB')
plt.legend(["Accuracy(%)","Precision(%)","Recall(%)","F1-Score(%)"],
           bbox_to_anchor = (1.05, 0.6))

# %%
plt.figure(figsize=(30, 30))
sb.factorplot(x="Feature Subset Selection Method",y="Accuracy(%)", hue="Algorithm", data=df, kind="bar",size=6).set(title='Comparision of Algorithms accuracy with Different Feature selection methods')
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sb.factorplot(x="Feature Subset Selection Method",y="F1-Score(%)", hue="Algorithm", data=df, kind="bar",size=6).set(title='Comparision of Algorithms F1-Score with Different Feature selection methods')
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
Feature_subset=['PCM','CS','Ano','IG','SFS','SBE']
Average_accuracy=[64.59,77.72,78.63,72.69,82.2,80.8]
plt.title('Average Accuracy of algorithms with feature selection methods')
plt.xlabel('Feature susbset selection methods')
plt.ylabel('Average accuracy(%)')
plt.bar(Feature_subset,Average_accuracy,color='maroon')
# Out:
# <BarContainer object of 6 artists>
